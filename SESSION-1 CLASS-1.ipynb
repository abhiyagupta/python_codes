# %%
#IDE (Integrated Development Environment) available for us

# %%
#1. Jupyter
#2. Spyder
#3. Pycharm

# %%
#What can be the uses for Python

#1. Web development
#2. Software development
#3. Automation and Automated Testing
#4. DBMS Programming
#5. Data Analytics, Data Science

# %%
#Like Python, WHich other languages are essential for Data Science

#1. SAS
#2. R
#3. Stata
#4. ORANGE
#5. SPSS

# %%
#First Programme in Python

print("Hello World")
# Out:
# Hello World

# %%
name = "Ayashkant Panda"
print(name)
# Out:
# Ayashkant Panda

# %%
print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 print(NAME)
#
# NameError: name 'NAME' is not defined

# %% [markdown]
# # HOW TO DEFINE VARIABLE, VALUES AND DATA TYPES

# %%
A = 100
B = 200

# %%
A
# Out:
# 100

# %%
print(A)
# Out:
# 100

# %%
A
B
# Out:
# 200

# %%
print(A)
print(B)
# Out:
# 100
# 200

# %%
C = A+B
print(C)
# Out:
# 300

# %% [markdown]
# # Arithmetic Funtions in Python

# %%
#additiion

C = A+B
print(C)
# Out:
# 300

# %%
# subtraction

D = A-B
print(D)
# Out:
# -100

# %%
# Multiplication

A = 10
B = 20
C = A*B

print(C)
# Out:
# 200

# %%
# division

A = 30
B = 5

C= A/B

print(C)
# Out:
# 6.0

# %%
# Power/Exponent

a = 10
b = 2

c = a**b

print(c)
# Out:
# 100

# %%
# Floor Division

A = 19
B = 10

C = A//B

print(C)
# Out:
# 1

# %%
# How many data types are covered

# 1. Integer
# 2. float
# 3. String

# %% [markdown]
# # Data Types in Python

# %%
A= 100

type(A)
# Out:
# int

# %%
A = -100

type(A)
# Out:
# int

# %%
A = 100.3

type(A)
# Out:
# float

# %%
A = 100 + 200

type(A)
# Out:
# int

# %%
A = range(0,100)

print(A)
type(A)
# Out:
# range(0, 100)
# range

# %%
A = "DV ANALYTICS 1"

type(A)
# Out:
# str

# %%
A = "D"

type(A)
# Out:
# str

# %% [markdown]
# # List, Tuple, Set and Dictionary

# %% [markdown]
# ## Lists

# %%
# Define List

movies = ['Fight CLub', 'the kerala story', 'Ratatouillie', 'WAKANDA FOREVER', 'Tu jhuti mai makkar']

# %%
print(movies)
# Out:
# ['Fight CLub', 'the kerala story', 'Ratatouillie', 'WAKANDA FOREVER', 'Tu jhuti mai makkar']

# %%
movies[0]
# Out:
# 'Fight CLub'

# %%
movies[4]
# Out:
# 'Tu jhuti mai makkar'

# %%
movies[2]
# Out:
# 'Ratatouillie'

# %%
movies[-1]
# Out:
# 'Tu jhuti mai makkar'

# %%
movies[-5]
# Out:
# 'Fight CLub'

# %% [markdown]
# ## Tuple

# %%
# Tuple

stu_name1 = ("Ramesh", "Deb", "Ayash", "Priya", "Ram")

# %%
type(stu_name)
# Out:
# tuple

# %%
stu_name
# Out:
# ('Ramesh', 'Deb', 'Ayash', 'Priya', 'Ram')

# %% [markdown]
# ## Set

# %%
stu_name = {'Ramesh', "Deb", "Ayashkant", 'Priya', "Ram"}
stu_name
# Out:
# {'Ayashkant', 'Deb', 'Priya', 'Ram', 'Ramesh'}

# %%
type(stu_name)
# Out:
# set

# %% [markdown]
# ## Dictionary

# %%
Stu_name_education = {"Ram" : "BTECH", "Deb" : "BCOM", "Ayash" : "MBA", "Ramesh" : "BSC IT"}
Stu_name_education
# Out:
# {'Ram': 'BTECH', 'Deb': 'BCOM', 'Ayash': 'MBA', 'Ramesh': 'BSC IT'}

# %%
# Key, 
# Value

Stu_name_education["Ram"]
# Out:
# 'BTECH'

# %%
type(Stu_name_education)
# Out:
# dict

# %% [markdown]
# # Can Data types of List and Tuple be updated

# %%
movies
# Out:
# ['Fight CLub',
#  'the kerala story',
#  'KGF',
#  'WAKANDA FOREVER',
#  'Tu jhuti mai makkar']

# %%
movies[2]
# Out:
# 'Ratatouillie'

# %%
movies[2] = "KGF"

# %%
movies[2]
# Out:
# 'KGF'

# %%
del movies[4]

# %%
movies
# Out:
# ['Fight CLub', 'the kerala story', 'KGF', 'WAKANDA FOREVER']

# %%
movies2 = ["Ratatouille", "KKKG", "Fast and Furious"]

# %%
movies3 = movies + movies2
movies3
# Out:
# ['Fight CLub',
#  'the kerala story',
#  'KGF',
#  'WAKANDA FOREVER',
#  'Ratatouille',
#  'KKKG',
#  'Fast and Furious']

# %%
movies3[6]
# Out:
# 'Fast and Furious'

# %%
stu_name1
# Out:
# ('Ramesh', 'Deb', 'Ayash', 'Priya', 'Ram')

# %%
del stu_name1[4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 del stu_name1[4]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
stu_name1[4] = "Pratik"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [61], in <cell line: 1>()
# ----> 1 stu_name1[4] = "Pratik"
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Mutable vs Immutable

# %%
stu_name1[-1]
# Out:
# 'Ram'

# %% [markdown]
# # How to Work with Data in Python

# %%
#pandas

import pandas as pd

# %%
stu_details = pd.DataFrame({"Stu_ID" : ['S1', 'S2', 'S3', 'S4', 'S5'], 
                           'Stu_name' : ['Ravi', "Arjun", "Ram", "Ayashkant", "Priya"], 
                           'Age' : [30, 31, 25, 27, 29], 
                           'Date of Enq' : ["02/01/2023", "04/01/2023", "20/01/2023", "02/04/2023", "02/01/2022" ], 
                           "Education" : ["BTECH", "MBA", "MTECH", "BSC", "BCOM"]})
# Out:
#   Input In [80]
#     'Date of Enq' : [02/01/2023, 04/01/2023, 20/01/2023, 02/04/2023, 02/01/2022 ],
#                       ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
stu_details
# Out:
#   Stu_ID   Stu_name  Age Date of Enq Education
# 0     S1       Ravi   30  02/01/2023     BTECH
# 1     S2      Arjun   31  04/01/2023       MBA
# 2     S3        Ram   25  20/01/2023     MTECH
# 3     S4  Ayashkant   27  02/04/2023       BSC
# 4     S5      Priya   29  02/01/2022      BCOM

# %% [markdown]
# # Describe the table

# %%
stu_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Stu_ID       5 non-null      object
#  1   Stu_name     5 non-null      object
#  2   Age          5 non-null      int64
#  3   Date of Enq  5 non-null      object
#  4   Education    5 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 328.0+ bytes

# %%
#Top 2

stu_details.head(2)
# Out:
#   Stu_ID Stu_name  Age Date of Enq Education
# 0     S1     Ravi   30  02/01/2023     BTECH
# 1     S2    Arjun   31  04/01/2023       MBA

# %%
# Bottom 2 

stu_details.tail(2)
# Out:
#   Stu_ID   Stu_name  Age Date of Enq Education
# 3     S4  Ayashkant   27  02/04/2023       BSC
# 4     S5      Priya   29  02/01/2022      BCOM

# %%
stu_details.shape
# Out:
# (5, 5)

# %% [markdown]
# # How to Create a table and Insert Values into it.

# %%
STU_ALL = pd.DataFrame(columns=['Stu_ID', "Stu_name", "Age", "Gender", "Work Exp"])
STU_ALL
# Out:
# Empty DataFrame
# Columns: [Stu_ID, Stu_name, Age, Gender, Work Exp]
# Index: []

# %%
list_of_all_values = [pd.Series(["S1", "Ram", 30, "M", 4], index = STU_ALL.columns), 
                     pd.Series(['S2', "Papu", 25, "M", 2], index = STU_ALL.columns),
                     pd.Series(['S3', "Priya", 24, "F", 2], index = STU_ALL.columns), 
                     pd.Series(['S4', "Ayash", 26, "M", 2], index = STU_ALL.columns), 
                     pd.Series(['S5', "Prabhoo", 25, "M", 2], index = STU_ALL.columns)]

list_of_all_values
# Out:
# [Stu_ID       S1
#  Stu_name    Ram
#  Age          30
#  Gender        M
#  Work Exp      4
#  dtype: object,
#  Stu_ID        S2
#  Stu_name    Papu
#  Age           25
#  Gender         M
#  Work Exp       2
#  dtype: object,
#  Stu_ID         S3
#  Stu_name    Priya
#  Age            24
#  Gender          F
#  Work Exp        2
#  dtype: object,
#  Stu_ID         S4
#  Stu_name    Ayash
#  Age            26
#  Gender          M
#  Work Exp        2
#  dtype: object,
#  Stu_ID           S5
#  Stu_name    Prabhoo
#  Age              25
#  Gender            M
#  Work Exp          2
#  dtype: object]

# %%
STU_ALL = STU_ALL.append(list_of_all_values, ignore_index = False)
STU_ALL
# Out:
# C:\Users\Debendra das\AppData\Local\Temp\ipykernel_10276\1788158282.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   STU_ALL = STU_ALL.append(list_of_all_values, ignore_index = False)
#   Stu_ID Stu_name Age Gender Work Exp
# 0     S1      Ram  30      M        4
# 1     S2     Papu  25      M        2
# 2     S3    Priya  24      F        2
# 3     S4    Ayash  26      M        2
# 4     S5  Prabhoo  25      M        2

# %%
STU_ALL["Institute"] = "DV Analytics"
STU_ALL
# Out:
#   Stu_ID Stu_name Age Gender Work Exp     Institute
# 0     S1      Ram  30      M        4  DV Analytics
# 1     S2     Papu  25      M        2  DV Analytics
# 2     S3    Priya  24      F        2  DV Analytics
# 3     S4    Ayash  26      M        2  DV Analytics
# 4     S5  Prabhoo  25      M        2  DV Analytics

# %%
STU_ALL = STU_ALL.drop(["Institute"], axis = 1)
STU_ALL
# Out:
#   Stu_ID Stu_name Age Gender Work Exp
# 0     S1      Ram  30      M        4
# 1     S2     Papu  25      M        2
# 2     S3    Priya  24      F        2
# 3     S4    Ayash  26      M        2
# 4     S5  Prabhoo  25      M        2

# %% [markdown]
# # IMPORTING and EXPORTING DATA TO PYTHON

# %% [markdown]
# ## EXCEL

# %%
med_2023_excel = pd.read_excel(r"C:\Users\Debendra das\Downloads\drive-download-20230506T083649Z-001\SESSION-1\A2.RAW_DATA\MED_STORE_2022.xlsx", sheet_name = "MED_AUS_DATA")
med_2023_excel
# Out:
#       CUSTOMER_ID    Company        CARD_REG_DATE CARD_ACTIVE  \
# 0      1000032547      MED +  2006-09-12 00:00:00           Y
# 1      1000032548  DR.REDDYS  2006-09-12 00:00:00           Y
# 2      1000032549   RELEGARE  2006-09-12 00:00:00           Y
# 3      1000032550        GSK  2006-09-12 00:00:00           Y
# 4      1000032551        GSK  2006-09-12 00:00:00           Y
# ...           ...        ...                  ...         ...
# 5107   1000037830   RELEGARE  2008-05-06 00:00:00           Y
# 5108   1000037831     APPOLO  2008-05-06 00:00:00           Y
# 5109   1000037832        GSK  2008-05-06 00:00:00           Y
# 5110   1000037833      MED +  2008-05-06 00:00:00           Y
# 5111   1000037834    RANBAXY  2008-05-06 00:00:00           Y
#
#             FIRST_USE_DTE  firstSTOR TITLE  GENDER  max spent        DOB  ...  \
# 0     2007-05-12 00:00:00       2587  Mrs.  Female      56.31 1984-09-15  ...
# ...

# %%
med_2023_excel.to_excel(r'C:\Users\Debendra das\Downloads\drive-download-20230506T083649Z-001\SESSION-1\A4.OUTPUT\med_2023.xlsx')

# %% [markdown]
# ## CSV

# %%
med_2023_CSV = pd.read_csv(r'C:\Users\Debendra das\Downloads\drive-download-20230506T083649Z-001\SESSION-1\A2.RAW_DATA\MED_STORE_2022.CSV')
med_2023_CSV
# Out:
#       CUSTOMER_ID    Company     CARD_REG_DATE CARD_ACTIVE     FIRST_USE_DTE  \
# 0      1000032547      MED +  12-09-2006 00:00           Y  12-05-2007 00:00
# 1      1000032548  DR.REDDYS  12-09-2006 00:00           Y  12-03-2007 00:00
# 2      1000032549   RELEGARE  12-09-2006 00:00           Y  12-02-2007 00:00
# 3      1000032550        GSK  12-09-2006 00:00           Y  12-03-2007 00:00
# 4      1000032551        GSK  12-09-2006 00:00           Y  12-05-2007 00:00
# ...           ...        ...               ...         ...               ...
# 5107   1000037830   RELEGARE  06-05-2008 00:00           Y  02-05-2009 00:00
# 5108   1000037831     APPOLO  06-05-2008 00:00           Y  06-10-2008 00:00
# 5109   1000037832        GSK  06-05-2008 00:00           Y  04-05-2009 00:00
# 5110   1000037833      MED +  06-05-2008 00:00           Y  10-06-2009 00:00
# 5111   1000037834    RANBAXY  06-05-2008 00:00           Y  04-05-2009 00:00
#
# ...

# %%
med_2023_CSV.to_csv(r'C:\Users\Debendra das\Downloads\drive-download-20230506T083649Z-001\SESSION-1\A4.OUTPUT\med_2023_csv.CSV')

# %% [markdown]
# ## Text file format

# %%
med_2023_text = pd.read_csv(r'C:\Users\Debendra das\Downloads\drive-download-20230506T083649Z-001\SESSION-1\A2.RAW_DATA\MED_STORE_2022.txt', sep=',')
med_2023_text
# Out:
#       CUSTOMER_ID    Company     CARD_REG_DATE CARD_ACTIVE     FIRST_USE_DTE  \
# 0      1000032547      MED +  12-09-2006 00:00           Y  12-05-2007 00:00
# 1      1000032548  DR.REDDYS  12-09-2006 00:00           Y  12-03-2007 00:00
# 2      1000032549   RELEGARE  12-09-2006 00:00           Y  12-02-2007 00:00
# 3      1000032550        GSK  12-09-2006 00:00           Y  12-03-2007 00:00
# 4      1000032551        GSK  12-09-2006 00:00           Y  12-05-2007 00:00
# ...           ...        ...               ...         ...               ...
# 5107   1000037830   RELEGARE  06-05-2008 00:00           Y  02-05-2009 00:00
# 5108   1000037831     APPOLO  06-05-2008 00:00           Y  06-10-2008 00:00
# 5109   1000037832        GSK  06-05-2008 00:00           Y  04-05-2009 00:00
# 5110   1000037833      MED +  06-05-2008 00:00           Y  10-06-2009 00:00
# 5111   1000037834    RANBAXY  06-05-2008 00:00           Y  04-05-2009 00:00
#
# ...

# %%
med_2023_text.to_csv(r'C:\Users\Debendra das\Downloads\drive-download-20230506T083649Z-001\SESSION-1\A4.OUTPUT\med_2023_text.txt', sep="|")

# %%
med_2023_excel
# Out:
#       CUSTOMER_ID    Company        CARD_REG_DATE CARD_ACTIVE  \
# 0      1000032547      MED +  2006-09-12 00:00:00           Y
# 1      1000032548  DR.REDDYS  2006-09-12 00:00:00           Y
# 2      1000032549   RELEGARE  2006-09-12 00:00:00           Y
# 3      1000032550        GSK  2006-09-12 00:00:00           Y
# 4      1000032551        GSK  2006-09-12 00:00:00           Y
# ...           ...        ...                  ...         ...
# 5107   1000037830   RELEGARE  2008-05-06 00:00:00           Y
# 5108   1000037831     APPOLO  2008-05-06 00:00:00           Y
# 5109   1000037832        GSK  2008-05-06 00:00:00           Y
# 5110   1000037833      MED +  2008-05-06 00:00:00           Y
# 5111   1000037834    RANBAXY  2008-05-06 00:00:00           Y
#
#             FIRST_USE_DTE  firstSTOR TITLE  GENDER  max spent        DOB  ...  \
# 0     2007-05-12 00:00:00       2587  Mrs.  Female      56.31 1984-09-15  ...
# ...

# %%
med_2023_excel.shape
# Out:
# (5112, 24)

# %%
med_2023_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5112 entries, 0 to 5111
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CUSTOMER_ID          5112 non-null   int64
#  1   Company              5112 non-null   object
#  2   CARD_REG_DATE        5112 non-null   object
#  3   CARD_ACTIVE          5112 non-null   object
#  4   FIRST_USE_DTE        5112 non-null   object
#  5   firstSTOR            5112 non-null   int64
#  6   TITLE                5112 non-null   object
#  7   GENDER               5112 non-null   object
#  8   max spent            5097 non-null   float64
#  9   DOB                  5112 non-null   datetime64[ns]
#  10  FTD                  5112 non-null   object
#  11  Age                  5112 non-null   int64
#  12  STATE_CODE           5112 non-null   object
#  13  POST_CODE            5112 non-null   int64
#  14  CUST_STAT            5112 non-null   object
# ...

# %%
med_2023_excel.head(10)
# Out:
#    CUSTOMER_ID    Company        CARD_REG_DATE CARD_ACTIVE  \
# 0   1000032547      MED +  2006-09-12 00:00:00           Y
# 1   1000032548  DR.REDDYS  2006-09-12 00:00:00           Y
# 2   1000032549   RELEGARE  2006-09-12 00:00:00           Y
# 3   1000032550        GSK  2006-09-12 00:00:00           Y
# 4   1000032551        GSK  2006-09-12 00:00:00           Y
# 5   1000032552     APPOLO  2007-07-09 00:00:00           Y
# 6   1000032553      CIPLA  2006-09-12 00:00:00           Y
# 7   1000032554     APPOLO  2006-09-12 00:00:00           Y
# 8   1000032555     APPOLO  2006-09-12 00:00:00           Y
# 9   1000032556      MED +  2006-09-12 00:00:00           Y
#
#          FIRST_USE_DTE  firstSTOR TITLE  GENDER  max spent        DOB  ...  \
# 0  2007-05-12 00:00:00       2587  Mrs.  Female      56.31 1984-09-15  ...
# 1  2007-03-12 00:00:00       4341   Ms.  Female     598.95 1974-07-15  ...
# 2  2007-02-12 00:00:00       1090  Mrs.  Female       1.56 1959-04-01  ...
# ...

# %%
med_2023_excel.tail(10)
# Out:
#       CUSTOMER_ID    Company        CARD_REG_DATE CARD_ACTIVE  \
# 5102   1000037825   GUARDIAN  2008-05-06 00:00:00           Y
# 5103   1000037826     APPOLO  2008-05-06 00:00:00           Y
# 5104   1000037827  DR.REDDYS  2008-05-06 00:00:00           Y
# 5105   1000037828        GSK  2008-05-06 00:00:00           Y
# 5106   1000037829       GENO  2008-05-06 00:00:00           Y
# 5107   1000037830   RELEGARE  2008-05-06 00:00:00           Y
# 5108   1000037831     APPOLO  2008-05-06 00:00:00           Y
# 5109   1000037832        GSK  2008-05-06 00:00:00           Y
# 5110   1000037833      MED +  2008-05-06 00:00:00           Y
# 5111   1000037834    RANBAXY  2008-05-06 00:00:00           Y
#
#             FIRST_USE_DTE  firstSTOR TITLE  GENDER  max spent        DOB  ...  \
# 5102   12/21/2008 0:00:00       1092   Mr.    Male     902.96 1948-09-08  ...
# 5103  2008-12-06 00:00:00       1091   Mr.    Male      31.20 1939-02-21  ...
# ...

# %%
med_2023_excel[100:201]
# Out:
#      CUSTOMER_ID    Company        CARD_REG_DATE CARD_ACTIVE  \
# 100   1000032647  DR.REDDYS    1/31/2008 0:00:00           Y
# 101   1000032648   GUARDIAN    1/31/2008 0:00:00           Y
# 102   1000032649    RANBAXY    1/31/2008 0:00:00           Y
# 103   1000032650   RELEGARE    1/31/2008 0:00:00           Y
# 104   1000032651      CIPLA    1/31/2008 0:00:00           Y
# ..           ...        ...                  ...         ...
# 196   1000032830  DR.REDDYS    2/28/2008 0:00:00           Y
# 197   1000032831   GUARDIAN    2/29/2008 0:00:00           Y
# 198   1000032832      MED +  2008-03-05 00:00:00           Y
# 199   1000032833   RELEGARE  2008-03-05 00:00:00           Y
# 200   1000032834   GUARDIAN  2008-03-05 00:00:00           Y
#
#            FIRST_USE_DTE  firstSTOR TITLE  GENDER  max spent        DOB  ...  \
# 100  2009-03-01 00:00:00       5646  Miss  Female     274.29 1982-11-01  ...
# ...

# %%
med_2023_excel.dtypes
# Out:
# CUSTOMER_ID                     int64
# Company                        object
# CARD_REG_DATE                  object
# CARD_ACTIVE                    object
# FIRST_USE_DTE                  object
# firstSTOR                       int64
# TITLE                          object
# GENDER                         object
# max spent                     float64
# DOB                    datetime64[ns]
# FTD                            object
# Age                             int64
# STATE_CODE                     object
# POST_CODE                       int64
# CUST_STAT                      object
# Avgsize spent                 float64
# CARD_STAT                      object
# RGSTN_TYPE_IND                 object
# NO_OF_TRIPS                     int64
# TOWN                           object
# EMAIL_IND                      object
# CONTACT_PREF                   object
# Average_Qty_PER_ACC           float64
# Spent amount                  float64
# dtype: object

# %%
med_2023_excel.describe()
# Out:
#         CUSTOMER_ID   firstSTOR     max spent          Age    POST_CODE  \
# count  5.112000e+03  5112.00000   5097.000000  5112.000000  5112.000000
# mean   1.000035e+09  2909.16471    296.052700    50.214397  4245.047340
# std    1.516922e+03  1037.71011    364.136141    14.950142  1472.169558
# min    1.000033e+09  1008.00000      1.560000    20.000000     3.000000
# 25%    1.000034e+09  2558.00000     78.830000    39.000000  2902.000000
# 50%    1.000035e+09  2700.00000    183.240000    50.000000  4211.000000
# 75%    1.000037e+09  3271.00000    392.720000    62.000000  6020.000000
# max    1.000038e+09  5739.00000  11727.670000    84.000000  6992.000000
#
#        Avgsize spent  NO_OF_TRIPS  Average_Qty_PER_ACC  Spent amount
# count    5112.000000  5112.000000          5112.000000   5112.000000
# mean       68.308355     5.308881            19.300788    324.115914
# std        54.531575     5.676040            15.424253    385.269245
# ...

# %%
med_2023_excel.columns.values
# Out:
# array(['CUSTOMER_ID', 'Company', 'CARD_REG_DATE', 'CARD_ACTIVE',
#        'FIRST_USE_DTE', 'firstSTOR', 'TITLE', 'GENDER', 'max spent',
#        'DOB', 'FTD', 'Age', 'STATE_CODE', 'POST_CODE', 'CUST_STAT',
#        'Avgsize spent', 'CARD_STAT', 'RGSTN_TYPE_IND', 'NO_OF_TRIPS',
#        'TOWN', 'EMAIL_IND', 'CONTACT_PREF', 'Average_Qty_PER_ACC',
#        'Spent amount'], dtype=object)

# %%
med_2023_excel.isnull().sum()
# Out:
# CUSTOMER_ID              0
# Company                  0
# CARD_REG_DATE            0
# CARD_ACTIVE              0
# FIRST_USE_DTE            0
# firstSTOR                0
# TITLE                    0
# GENDER                   0
# max spent               15
# DOB                      0
# FTD                      0
# Age                      0
# STATE_CODE               0
# POST_CODE                0
# CUST_STAT                0
# Avgsize spent            0
# CARD_STAT                0
# RGSTN_TYPE_IND           0
# NO_OF_TRIPS              0
# TOWN                     0
# EMAIL_IND                0
# CONTACT_PREF           893
# Average_Qty_PER_ACC      0
# Spent amount             0
# dtype: int64

# %%
med_2023_excel.isnull()
# Out:
#       CUSTOMER_ID  Company  CARD_REG_DATE  CARD_ACTIVE  FIRST_USE_DTE  \
# 0           False    False          False        False          False
# 1           False    False          False        False          False
# 2           False    False          False        False          False
# 3           False    False          False        False          False
# 4           False    False          False        False          False
# ...           ...      ...            ...          ...            ...
# 5107        False    False          False        False          False
# 5108        False    False          False        False          False
# 5109        False    False          False        False          False
# 5110        False    False          False        False          False
# 5111        False    False          False        False          False
#
#       firstSTOR  TITLE  GENDER  max spent    DOB  ...  CUST_STAT  \
# ...

# %% [markdown]
# # Reading Data from Servers

# %%
import pandas as pd
import pyodbc
from sqlalchemy import create_engine, event
from sqlalchemy.engine.url import URL

conn_str = ("Driver={SQL Server Native Client 11.0};"
            "Server=.;"
            "Database=BATCH_202209;"
            "Trusted_Connection=yes;")

conn_url = URL.create("mssql+pyodbc", query={"odbc_connect": conn_str}) # Creating url

engine = create_engine(conn_url) # Creating Engine

# sql_query="SELECT * from information_schema.columns" # Writing SQL Query

MED_2022_SQL = pd.read_sql_table('MED_2022', engine)

MED_2022_SQL.head(100)

# %%
# HOW TO READ DATA FROM SQL DATABASES

##### FOR IMPORTING DATA FROM SQL DATABASE
import pandas as pd
import pyodbc # IMPORT PYODBC TO GET CONNECTED WITH DATABASE

cnxn_str = ("Driver={SQL Server Native Client 11.0};"# WRITE DRIVER NAME
            "Server=.;" # WRITE SERVER NAME, HERE LOCAL SERVER IS GIVEN
            "Database=BATCH_202209;" # DATABASE NAME
            "Trusted_Connection=yes;") 
cnxn = pyodbc.connect(cnxn_str) #CONNECTION VARIABLE

sql_query="SELECT DISTINCT [Company] FROM MED_2022"  #QUERY VARIABLE

unq_company = pd.read_sql(sql_query, cnxn) #CODE FOR READING SQL TABLE
unq_company

# %%
# HOW TO READ DATA FROM SQL DATABASES

##### FOR IMPORTING DATA FROM SQL DATABASE
import pandas as pd
import pyodbc # IMPORT PYODBC TO GET CONNECTED WITH DATABASE

cnxn_str = ("Driver={SQL Server Native Client 11.0};"# WRITE DRIVER NAME
            "Server=.;" # WRITE SERVER NAME, HERE LOCAL SERVER IS GIVEN
            "Database=BATCH_202209;" # DATABASE NAME
            "Trusted_Connection=yes;") 
cnxn = pyodbc.connect(cnxn_str) #CONNECTION VARIABLE

sql_query="SELECT CUSTOMER_ID,Company,GENDER,Age,STATE_CODE,Spent_amount FROM MED_2022"  #QUERY VARIABLE

MED_SELECT = pd.read_sql(sql_query, cnxn) #CODE FOR READING SQL TABLE
MED_SELECT

# %%
# HOW TO WRITE DATA TO A SQL DATABASES

import pandas as pd
import pyodbc
from sqlalchemy import create_engine, event
from sqlalchemy.engine.url import URL

conn_str = ("Driver={SQL Server Native Client 11.0};"
            "Server=.;"
            "Database=BATCH_202209;"
            "Trusted_Connection=yes;")

conn_url = URL.create("mssql+pyodbc", query={"odbc_connect": conn_str}) # Creating url

engine = create_engine(conn_url) # Creating Engine

MED_SELECT.to_sql('MED_SELECT_python', engine) # Without Sql Query we have to write pd.read_sql_table('table_name',engine)
